# %%
def fasta(x):
    with open(path, "r") as fasta:
        f = fasta.read() #read file
        f = f.splitlines() #remove '\n' in the end of strings
        length = []
        for n, text in enumerate(f): #count the length of each string with sequenсes
            if n % 2 == 1:
                length.append(len(text))


    import matplotlib.pyplot as plt
    import seaborn as sns
    
    plt.rcParams['figure.figsize'] = [10, 6] #the size of image
    plt.rcParams['font.size'] = 20 #the size of values
    plt.rcParams['savefig.bbox'] = 'tight'

    sns.set(style = 'darkgrid') #style
    
    #histogram whithout density plot
    sns.distplot(length, color = sns.color_palette("bright")[4], bins = 100, kde=False)
    plt.xlabel('length', color = 'orange', size = 18)
    plt.title('Distribution of read lengths', color = 'orange', size = 25)

    plt.savefig('Task2_Histogram.png')
    
path = input('Input path to fasta-file on your conputer. Use back slash (\)',)
fasta(path)
# Out:
# Input path to fasta-file on your conputer. Use back slash (\)D:\Shared_folder\fasta.fna
